# %%
# %run finance_assistant_functions.ipynb

# %%
pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.2/806.2 kB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 15.2 MB/s eta 0:00:00
# ...

# %%
pip install youtube-transcript-api

# %%
pip install youtube-search

# %%
pip install pytube
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 852.4 kB/s eta 0:00:00
# ...

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# ...

# %%
pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 50.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 92.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 9.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.0 MB/s eta 0:00:00
# ...

# %%
# can i buy home by 2024 ?

# %%
api_key ="sk-9R5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxh9H"

# %%
import os
os.environ["OPENAI_API_KEY"] = api_key

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.schema import Document
from ipywidgets import Layout
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML
import os
from langchain.vectorstores import Chroma
from langchain.chains.question_answering import load_qa_chain
from langchain.tools import YouTubeSearchTool
from langchain.document_loaders import YoutubeLoader
import ast

# Define constants
CONTEXT = "context"
HUMAN_INPUT = "human_input"
CHAT_HISTORY_INDICATOR = "chat_history_indicator"
OPENAI_CHAT_MODEL = "gpt-3.5-turbo-16k"
# OPENAIAPIKEY = "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"
# OPENAI_API_KEY = os.environ.get(OPENAIAPIKEY)


script_chain = None

def return_generate_ai_script(template_text: str, user_query: str, all_docs: list) -> str:
    """
    Generate an AI script and append it to a template.

    Args:
        template_text (str): Template for LLM model.
        message_text (str): User Question.
        retrieved_docs (list): List of retrieved documents.

    Returns:
        str: AI output string.
    """
    global script_chain

    # Load an embedding model from OpenAI
    embeddings = OpenAIEmbeddings()

    # Transform my docs into vectors and store that into a database (chroma) for managing and querying the embeddings
    docsearch = Chroma.from_texts(all_docs, embeddings, metadatas=[{"source": i} for i in range(len(all_docs))])
    # from_documents
    #print(all_docs)


    # Use cosign similarity to perform the search for documents similar to the user query
    similar_docs = docsearch.similarity_search(user_query)

    # Initialize script_chain if it doesn't exist
    if script_chain is None:

        # Input for the prompt
        prompt = PromptTemplate(input_variables=[CHAT_HISTORY_INDICATOR, HUMAN_INPUT, CONTEXT], template=template_text)

        # Input for the Memory class
        memory = ConversationBufferMemory(memory_key=CHAT_HISTORY_INDICATOR, input_key = HUMAN_INPUT )

        # Load LLM model
        llm = ChatOpenAI(model_name=OPENAI_CHAT_MODEL, temperature=0)

        # Feed LLM model, memory object, and prompt to the Q and A chain library
        script_chain = load_qa_chain(llm = llm, chain_type="stuff", memory= memory, prompt=prompt)

    gen_ai_output = script_chain({"input_documents": similar_docs, HUMAN_INPUT: user_query}, return_only_outputs=True)

    print('Chain memory: ', script_chain.memory.buffer)

    return gen_ai_output['output_text']


def return_youtube_docs(query, num_of_docs):
    tool = YouTubeSearchTool()
    search_result = tool.run(query + ', '+ str(num_of_docs))
    result_list = ast.literal_eval(search_result)

    all_docs = []

    for link in result_list:

        loader = YoutubeLoader.from_youtube_url(
            link, add_video_info=True,  language=["hi", "id", "en"], #
    translation="hi",
        )

        doc = loader.load()
        all_docs.append(doc[0].page_content)

    return all_docs

# %%
template_text = """You are a finance support chatbot. Given the following extracted parts of a long document and a question, create a final answer.

{context}

{chat_history_indicator}

User Question: {human_input}

Chatbot:"""

# %%
# Define the function to handle the "Generate Response" button click and display the result
def generate_response(b):
    global template_text

    question = text_box.value

    all_docs = return_youtube_docs(question, num_of_docs = 5)

    bot_response = return_generate_ai_script(template_text = template_text, user_query = question, all_docs = all_docs)

    # Check if there are relevant documents or not and display the output
    with output:
        if not bot_response:
            print(f"No relevant information found with the query: {question}")
        else:
            print('\n\n',bot_response,'\n\n')
            print('************************************************************')

# %%
def restart_session(b):
    global script_chain

    # Re-initialize script_chain as None
    script_chain = None

    # Clear previous outputs in the output widget
    output.clear_output(
        # wait=True
    )

    # Clear the text in the text box
    text_box.value = ""

# %%
# Create the widgets

# Create a text input box for the user to type their question
text_box = widgets.Text(
    description='Type your question:',  # Add a description label
    layout=widgets.Layout(width='50%'),  # Set the width of the text box
    style={'description_width': 'initial'}  # Adjust the description width
)

# Create a button to restart the session and assign an event handler
submit_button = widgets.Button(description='Restart Session')
submit_button.on_click(restart_session)

# Create a button to generate a response and assign an event handler
generate_button = widgets.Button(description='Generate Response')
generate_button.on_click(generate_response)

# Create an HBox to place the buttons side by side
buttons_box = widgets.HBox([submit_button, generate_button])

# Create the output widget for displaying the results

# Create an output widget with specific layout and styling
output = widgets.Output(
    layout=widgets.Layout(width='90%', height='300px', border='1px solid gray', overflow='auto')
)

# Define an HTML title for the application
title_html = '<h1><b>AI Finance Assistant - TechLink Communications</b></h1>'

# Create an HTML widget to display the title
title_widget = HTML(title_html)

# Display the widgets and output

# Display the title
display(title_widget)

# Display a line break
display(HTML("<br>"))

# Display the text input box and buttons side by side
display(text_box)
display(buttons_box)

# Display the output widget for displaying results
display(output)
# Out:
# <h1><b>AI Finance Assistant - TechLink Communications</b></h1>
# <br>
# Text(value='', description='Type your question:', layout=Layout(width='50%'), style=TextStyle(description_widt…
# ...
# Output(layout=Layout(border_bottom='1px solid gray', border_left='1px solid gray', border_right='1px solid gra…
